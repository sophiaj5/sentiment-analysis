# %%
#imports
import pandas as pd
import numpy as np
import matplotlib as plt
from nltk.corpus import stopwords
from cleantext import clean
import re
from nltk.stem import WordNetLemmatizer

# %%
#pulling in cleaned data
df = pd.read_csv('../dataset/cleaned_data')
df
# Out:
#                                                   text    sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#                timestamp                                   user     platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# 1    2023-01-15 08:45:00                          CommuterX        Twitter
# 2    2023-01-15 15:45:00                          FitnessFan      Instagram
# 3    2023-01-15 18:20:00                          AdventureX       Facebook
# 4    2023-01-15 19:55:00                          ChefCook        Instagram
# ..                   ...                                    ...          ...
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# 731  2020-11-15 15:15:00    VirtualTalentShowSuccessHighSchool    Instagram
#
#                                           hashtags  retweets  likes  \
# 0        #Nature #Park                                  15.0   30.0
# 1        #Traffic #Morning                               5.0   10.0
# 2        #Fitness #Workout                              20.0   40.0
# 3        #Travel #Adventure                              8.0   15.0
# 4        #Cooking #Food                                 12.0   25.0
# ..                                             ...       ...    ...
# 727         #ScienceFairWinner #HighSchoolScience       20.0   39.0
# 728    #SurpriseCelebration #HighSchoolFriendship       25.0   48.0
# 729      #CommunityGiving #HighSchoolPhilanthropy       22.0   42.0
# 730         #CulturalCelebration #HighSchoolUnity       21.0   43.0
# 731   #VirtualEntertainment #HighSchoolPositivity       24.0   47.0
#
#           country  year  month  day  hour
# 0       USA        2023      1   15    12
# 1       Canada     2023      1   15     8
# 2     USA          2023      1   15    15
# 3       UK         2023      1   15    18
# 4      Australia   2023      1   15    19
# ..            ...   ...    ...  ...   ...
# 727            UK  2017      8   18    18
# 728           USA  2018      6   22    14
# 729        Canada  2019      4    5    17
# 730            UK  2020      2   29    20
# 731           USA  2020     11   15    15
#
# [732 rows x 13 columns]

# %%
#function to preprocess the text
#text to lowercase, removes stopwords, removes punctuation, and lemmatizes

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text_column):
    preprocessed_text = []
    for post in text_column:
        post = post.lower().split() #turns text into lowercase
        filtered_post = [p for p in post if not p in stop_words] #removes stop words
        clean_post = ' '.join(filtered_post)
        clean_post = re.sub(r'[^\w\s]', '', clean_post)
        final_post = lemmatizer.lemmatize(clean_post)
        preprocessed_text.append(final_post)
    
    return clean(preprocessed_text, no_emoji=True) #returns text without emojis

# %%
preprocess(df['text'])
# Out:
# "['enjoying beautiful day park', 'traffic terrible morning', 'finished amazing workout ', 'excited upcoming weekend getaway', 'trying new recipe dinner tonight', 'feeling grateful little things life', 'rainy days call cozy blankets hot cocoa', 'new movie release mustwatch', 'political discussions heating timeline', 'missing summer vibes beach days', 'published new blog post check out', 'feeling bit weather today', 'exploring citys hidden gems', 'new year new fitness goals ', 'technology changing way live', 'reflecting past looking ahead', 'adopted cute furry friend ', 'latenight gaming session friends', 'attending virtual conference ai', 'winter blues got feeling low', 'sipping coffee enjoying good book', 'exploring world virtual reality', 'productive day ticking todo list', 'finished challenging workout routine', 'celebrating milestone work ', 'sunday brunch friends', 'learning new language personal growth', 'quiet evening good book', 'reflecting importance mental health', 'new painting progress ', 'weekend road trip explore scenic views', 'enjoying cup tea watching sunset', 'coding new project enthusiasm', 'feeling inspired attending workshop', 'winter sports day local park', 'quality time family weekend', 'attending live music concert tonight', 'practicing mindfulness meditation', 'trying new dessert recipe', 'excited upcoming gaming tournament', 'planning garden makeover spring', 'celebrating friends birthday tonight ', 'feeling accomplished productive day', 'cozy evening good movie', 'exploring local art galleries weekend', 'new book release favorite author', 'attending virtual reality meetup', 'reflecting beauty nature', 'cooking special dinner loved ones', 'feeling optimistic week ahead', 'starting new fitness challenge tomorrow ', 'sunday bike ride scenic trails', 'cant believe injustice happening society', 'feeling sense fear watching thriller movie', 'heartbroken hearing news natural disaster', 'state worlds environment disgusting', 'pure happiness celebrating loved ones achievement', 'laughter best medicineenjoying comedy show', 'sharing love positive vibes everyone ', 'amusing incident brightened day', 'enjoying quiet evening book tea', 'admiring beauty nature peaceful hike', 'sending affectionate vibes followers', 'experiencing awe breathtaking sunset', 'disappointed service local restaurant', 'surprise gift friend made day', 'finding acceptance midst lifes challenges', 'overflowing adoration adorable pet ', 'anticipating thrilling adventure coming weeks', 'bitter experience turned valuable lesson', 'finding calmness midst busy day', 'confusion clouds mind navigate decisions', 'excitement building upcoming vacation', 'kindness witnessed today restored faith humanity', 'pride achieving personal milestone', 'moment shame standing injustice', 'fuming anger heated argument', 'fear unknown keeping night', 'heartfelt sadness bidding farewell dear friend', 'state corruption society utterly disgusting', 'overflowing happiness welcoming new family member', 'laughter key joyattending standup comedy show', 'sending love followers beautiful day ', 'amused antics petits pure amusement', 'enjoying every moment trippure enjoyment', 'admiring dedication volunteers local charity', 'sending affectionate vibes friends family', 'awestruck beauty night sky', 'disappointed lack progress personal project', 'surprise visit old friend brought tears joy', 'embracing acceptance lifes ups downs', 'overflowing adoration cute rescue puppy ', 'anticipating release muchawaited movie', 'bitter experience customer service department', 'finding calmness amidst chaos daily life', 'confusion reigns try make sense recent events', 'excitement building surprise birthday party', 'witnessed act kindness made day', 'pride completing challenging fitness challenge', 'moment shame speaking injustice', 'reflecting beauty diversity world', 'excitement quiet evening good book', 'feeling bitter unfairness workplace', 'calmness prevails practice mindfulness', 'con ...
